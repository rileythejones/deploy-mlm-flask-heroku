# %%
import pandas as pd 
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///db.sqlite3', echo=False)

# %%
df = pd.read_csv('SpotifyAudioFeaturesApril2019.csv')

# %%
df
# Out:
#                   artist_name                track_id  \
# 0                          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1                          YG  1tHDG53xJNGsItRA3vfVgs
# 2                       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3                  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4                  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
# ...                       ...                     ...
# 130658            Calum Scott  0cvfSKcm9VeduwyYPrxtLx
# 130659           Saint Claire  43MP9F7UzvfilSrw2SqZGJ
# 130660              Mike Stud  4TWlUuFk81NGUNKwndyS5Q
# 130661               D Savage  5iGBXzOoRo4sBTy8wdzMyK
# 130662  Banda Los Sebastianes  7LNtyuekYHiZ99UxkrfCQR
#
#                                             track_name  acousticness  \
# 0       Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820
# 1                         BAND DRUM (feat. A$AP Rocky)      0.024400
# 2                                        Radio Silence      0.025000
# ...

# %%
df.to_sql('songs', index=False, con=engine)

# %%
songs_df =  pd.read_sql_table('songs', 'sqlite:///db.sqlite3')

# %%
songs_df
# Out:
#                   artist_name                track_id  \
# 0                          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1                          YG  1tHDG53xJNGsItRA3vfVgs
# 2                       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3                  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4                  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
# ...                       ...                     ...
# 130658            Calum Scott  0cvfSKcm9VeduwyYPrxtLx
# 130659           Saint Claire  43MP9F7UzvfilSrw2SqZGJ
# 130660              Mike Stud  4TWlUuFk81NGUNKwndyS5Q
# 130661               D Savage  5iGBXzOoRo4sBTy8wdzMyK
# 130662  Banda Los Sebastianes  7LNtyuekYHiZ99UxkrfCQR
#
#                                             track_name  acousticness  \
# 0       Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820
# 1                         BAND DRUM (feat. A$AP Rocky)      0.024400
# 2                                        Radio Silence      0.025000
# ...

# %%
songs_df = pd.read_csv(infile)
y = songs_df[songs_df.columns[:3]]
X = songs_df[songs_df.columns[3:]]
my_model = create_model(preprocess(X))
moz_cols = songs_df[songs_df.artist_name == 'Wolfgang Amadeus Mozart'].index
input_song = songs_df.iloc[moz_cols[0]]
input_song = pd.DataFrame(input_song).T
print(input_song.columns)
input_song = input_song[:][3:]
print(input_song.shape)
results = suggest_songs(input_song, my_model)
# moz_cols = songs_df[songs_df.artist_name == 'Wolfgang Amadeus Mozart'].index
# X.iloc[moz_cols]
# suggest_songs(moz_cols[0], model)
# recommendations = model.kneighbors(preprocess(X.iloc[moz_cols[0]]))[1][0]
# y.iloc[recommendations].reset_index(drop=True)
